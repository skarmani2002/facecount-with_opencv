# %%
#import required libraries 
#import OpenCV library
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
#importing time library for speed comparisons of both classifiers
import time 
# %matplotlib inline

# %%
def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
test1 = cv2.imread('data/test5.jpg')
gray_img = cv2.cvtColor(test1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img, cmap='gray')

# %%
haar_face_cascade = cv2.CascadeClassifier('data/haarcascade_frontalface_alt.xml')
faces = haar_face_cascade.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5);  
 
#print the number of faces found 
print('Faces found: ', len(faces))
# Out:
# Faces found:  8

# %%
#import required libraries 
#import OpenCV library
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
#importing time library for speed comparisons of both classifiers
import time 
# %matplotlib inline
haar_face_cascade = cv2.CascadeClassifier('data/haarcascade_frontalface_alt.xml')

def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

def detect_faces(f_cascade, colored_img, scaleFactor = 1.2):
    img_copy = colored_img.copy()
    gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
    faces = f_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5);
    
    for (x, y, w, h) in faces:
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
    return img_copy,faces



faces_detected_img,faces = detect_faces(haar_face_cascade, test2) 


plt.title("Faces counts")
plt.title(len(faces))
plt.imshow(convertToRGB(faces_detected_img))

# %%
test2 = cv2.imread('data/test4.jpg')  
 
#call our function to detect faces 
faces_detected_img,faces = detect_faces(haar_face_cascade, test2,scaleFactor=1.3)  
 
#convert image to RGB and show image 
plt.title("Faces counts")
plt.title(len(faces))

plt.imshow(convertToRGB(faces_detected_img))
